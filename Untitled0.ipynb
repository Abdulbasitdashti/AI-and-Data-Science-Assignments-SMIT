# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulbasitdashti/AI-and-Data-Science-Assignments-SMIT/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
 pred = model.predict("/content/Laptop.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1793/590252532.py in <cell line: 0>()
# ----> 1 pred = model.predict("/content/Laptop.jpg")
#
# /usr/local/lib/python3.13/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     558         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559             self.predictor.set_prompts(prompts)
# --> 560         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     561
#     562     def track(
#
# /usr/local/lib/python3.13/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     242             return self.stream_inference(source, model, *args, **kwargs)
#     243         else:
# ...

# %%
pred[0].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1793/2927835063.py in <cell line: 0>()
# ----> 1 pred[0].plot()
#
# NameError: name 'pred' is not defined

# %%
 pred = model.predict("/content/streetimg.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1793/2300619022.py in <cell line: 0>()
# ----> 1 pred = model.predict("/content/streetimg.jpg")
#
# /usr/local/lib/python3.13/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     558         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559             self.predictor.set_prompts(prompts)
# --> 560         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     561
#     562     def track(
#
# /usr/local/lib/python3.13/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     242             return self.stream_inference(source, model, *args, **kwargs)
#     243         else:
# ...

# %%
pred[0].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1793/2927835063.py in <cell line: 0>()
# ----> 1 pred[0].plot()
#
# NameError: name 'pred' is not defined

# %%
def prediction_image(image):
  prediction = model.predict(image)
  return prediction[0].plot()

# %%
import gradio as gr

# %%
app = gr.Interface(fn = prediction_image, inputs="image", outputs="image", title = "YOLO Model Prediction")

# %%
app.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fb7b7dc0e7d0e7ba59.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fb7b7dc0e7d0e7ba59.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import os

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="WrxpUALSHUtmqWpwrQSC")
project = rf.workspace("muhammad-yusri").project("gun-ogblr")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Gun-1 in yolov11:: 100%|██████████| 5984/5984 [00:00<00:00, 9738.69it/s]

# %%
import os

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2408/2355735933.py in <cell line: 0>()
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aleemaparakatta/cats-and-dogs-mini-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 21.9M/21.9M [00:02<00:00, 10.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aleemaparakatta/cats-and-dogs-mini-dataset/versions/1

# %%
model.train(data="/content/Gun-1/data.yaml", epochs=10, batch=32)
# Out:
# Ultralytics 8.4.155 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
